# %%
import sys
sys.path.append(r"E:\Code_Projects\Brokers\fyers")

# %%
from trading_app.broker.symbol_pd import FyersSymbolService

# %%
service = FyersSymbolService()

# %%
master_df =service.fetch_symbol_master_df()

# %%
master_df.to_csv("./masterdf.csv")
